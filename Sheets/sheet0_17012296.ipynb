# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

iris = datasets.load_iris()
X = pd.DataFrame(iris.data)
X.columns = ['sepal length', 'sepal width', 'petal length', 'petal width']
y = pd.DataFrame(iris.target)
y.columns = ['species']
target_names = iris.target_names

# %%
plt.title('sepal length')
plt.hist(X['sepal length'])
plt.show()

# %%
plt.title('sepal width')
plt.hist(X['sepal width'])
plt.show()

# %%
plt.title('petal length')
plt.hist(X['petal length'])
plt.show()

# %%
plt.title('petal width')
plt.hist(X['petal width'])
plt.show()

# %%
X.plot.scatter(x='sepal length', y='sepal width')
plt.show()

# %%
X.plot.scatter(x='sepal length', y='petal length')
plt.show()

# %%
X.plot.scatter(x='sepal length', y='petal width')
plt.show()

# %%
X.plot.scatter(x='sepal width', y='petal length')
plt.show()

# %%
X.plot.scatter(x='sepal width', y='petal width')
plt.show()

# %%
X.plot.scatter(x='petal length', y='petal width')
plt.show()

# %%
pd.plotting.scatter_matrix(X, c=y['species'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X['sepal length'],X['sepal width'],X['petal length'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X['sepal length'],X['sepal width'],X['petal width'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X['sepal length'],X['petal length'],X['petal width'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X['sepal width'],X['petal length'],X['petal width'])
plt.show()

# %%
matrix = X.corr()
print(matrix)
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.117570      0.871754     0.817941
# sepal width      -0.117570     1.000000     -0.428440    -0.366126
# petal length      0.871754    -0.428440      1.000000     0.962865
# petal width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# Whenever a corroleation is negative then there is less correlation between those two features, and positive there is a bigger correlation and that the features are related.

# %%
X.boxplot('sepal length')
plt.show()

# %%
X.boxplot('sepal width')
plt.show()

# %%
X.boxplot('petal length')
plt.show()

# %%
X.boxplot('petal width')
plt.show()

# %%
X.boxplot()
plt.show()
